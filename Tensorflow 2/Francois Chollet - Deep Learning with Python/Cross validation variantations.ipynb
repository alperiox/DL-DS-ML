# %%
import tensorflow as tf
from tensorflow.keras import layers, optimizers, models
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
N = 10000
K = 16
dataset = np.random.random((N,K))
X = dataset[:,:-1]
Y = dataset[:,-1]
print(X.shape, Y.shape)
# Out:
# (10000, 15) (10000,)

# %%
def hold_out_validation(X,Y, test_rate = .2):
  """
  Gets some input and target data and returns validation-test-train splits.
  Args:
    X (ndarray): Input data
    Y (ndarray): Target data
    test_rate (float): Split rate for test dataset 
  """
  assert X.shape[0] == len(Y),"Input and target must've same number of samples"
  N = X.shape[0]
  val_rate = (1-test_rate)/2
  num_val = int(N*val_rate)
  num_test = int(N*test_rate)

  # split the data to test and validation sets
  x_val, y_val = X[:num_val], Y[:num_val]
  x_test, y_test = X[-num_test:], Y[-num_test:]
  # update X and Y according to splits
  x_train, y_train = X[num_val:-num_test], Y[num_val:-num_test]

  return (x_train, y_train), (x_val, y_val), (x_test, y_test)

# %%
(x_train, y_train), (x_val, y_val), (x_test, y_test) = hold_out_validation(X,Y)
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (4000, 15) (4000,)
# (4000, 15) (4000,)
# (2000, 15) (2000,)

# %%
EPOCHS = 10
BATCH_SIZE = 64
def build_model():
  # define the model
  model = models.Sequential([
    layers.Dense(64, activation = 'relu', input_shape = (x_train.shape[1],)),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(1)
  ])
  model.compile(optimizer = optimizers.RMSprop(lr=0.001),
              loss = 'mse',
              metrics = ['mae'])
  return model
model = build_model()
r = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = EPOCHS, batch_size = BATCH_SIZE)
# evaluate test data
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0929 - mae: 0.2595 - val_loss: 0.1040 - val_mae: 0.2696
# Epoch 2/10
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0885 - mae: 0.2542 - val_loss: 0.0890 - val_mae: 0.2550
# Epoch 3/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0860 - mae: 0.2502 - val_loss: 0.0895 - val_mae: 0.2556
# Epoch 4/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0854 - mae: 0.2504 - val_loss: 0.0905 - val_mae: 0.2565
# Epoch 5/10
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0848 - mae: 0.2494 - val_loss: 0.0875 - val_mae: 0.2532
# Epoch 6/10
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0837 - mae: 0.2478 - val_loss: 0.0890 - val_mae: 0.2547
# Epoch 7/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0823 - mae: 0.2456 - val_loss: 0.0941 - val_mae: 0.2608
# Epoch 8/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0819 - mae: 0.2456 - val_loss: 0.1054 - val_mae: 0.2728
# Epoch 9/10
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0816 - mae: 0.2446 - val_loss: 0.0870 - val_mae: 0.2527
# Epoch 10/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0805 - mae: 0.2428 - val_loss: 0.0912 - val_mae: 0.2571
# 63/63 [==============================] - 0s 926us/step - loss: 0.0896 - mae: 0.2561
# [0.08962637931108475, 0.2560900151729584]
